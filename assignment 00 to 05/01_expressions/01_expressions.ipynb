# %%
import random
print("01_dicesimulator")

def roll_dice():
  die1:int = random.randint(1, 6)
  die2:int = random.randint(1, 6)
  total:int = die1 + die2
  print(f"Total of two dies: {total}")

def main():
  die1:int = 10
  print("die1 in main() start as :" + str(die1))
  roll_dice()
  roll_dice()
  roll_dice()
  print("die1 in main() is: " + str(die1))

if __name__ == "__main__":
  main()
# Out:
# 01_dicesimulator
# die1 in main() start as :10
# Total of two dies: 4
# Total of two dies: 7
# Total of two dies: 6
# die1 in main() is: 10

# %%
print("02_e=mc2")

def energy():
  c:float = 299792458
  m:float = float(input("Enter kilos of mass: "))
  print("e - m*c^2")
  print("Mass = " + str(m) + " kg")
  print("C = " + str(c) + " m/s")
  print("e = " + str(m * c ** 2) + " jules")

if __name__ == "__main__":
  energy()
# Out:
# 02_e=mc2
# Enter kilos of mass: 450
# e - m*c^2
# Mass = 450.0 kg
# C = 299792458 m/s
# e = 4.0443983043156795e+19 jules

# %%
print("03_feet_to_inches")

inch: int = 12

def foot():
  feet:float = float(input("Enter feet to get your answer in inches: "))
  print(f"There are {inch * feet} inches in {feet} feet.")

if __name__ == "__main__":
  foot()
# Out:
# 03_feet_to_inches
# Enter feet and I will convert into inches: 22
# There are 264.0 inches in 22.0 feet.

# %%
import math

print("04_pythagorean_theorem")

def triangle():
  ab:float = float(input("Enter the length of the side ab: "))
  ac:float = float(input("Enter the length of the side ac: "))
  bc:float = math.sqrt(ab**2 + ac**2)
  print(f"The length of bc (the hypotenuse) is : {bc}")

if __name__ == "__main__":
  triangle()
# Out:
# 04_pythagorean_theorem
# Enter the length of the side ab: 4
# Enter the length of the side ac: 4
# The length of bc (the hypotenuse) is : 5.656854249492381

# %%
print("05_remainder_division.")

def reminder():
  num1: int = int(input("Enter an integer to be divided: "))
  num2: int = int(input("Enter an integer to divide br: "))
  quotient:int = num1 // num2
  reminder:int = num1 % num2
  print(f"The result of this division is {quotient} with a reminder of {reminder}")

if __name__ == "__main__":
  reminder()
# Out:
# 05_remainder_division
# Enter an integer to be divided: 56
# Enter an integer to divide br: 3
# The result of this division is 18 with a reminder of 2

# %%
import random
print("06_rolldice")
def dice():
  die1:int = random.randint(1,6)
  die2:int = random.randint(1,6)
  total:int = int(die1 + (die2))
  print("First die: " + str(die1))
  print("Second die: " + str(die2))
  print(f"Total of two dies is : {total}")

if __name__ == "__main__":
  dice()
# Out:
# 06_rolldice
# First die: 4
# Second die: 5
# Total of two dies is : 9

# %%
from re import S
print("06_seconds_in_year.")

days_in_year:int = 365
hours_per_day:int = 24
minutes_per_hour:int = 60
seconds_per_minute:int = 60

def seconds():
  print(f"There are {days_in_year * hours_per_day * minutes_per_hour * seconds_per_minute} seconds in a year!")

if __name__ == "__main__":
  seconds()
# Out:
# 06_seconds_in_year.
# There are 31536000 seconds in a year!

# %%
print("07_tiny_mad_lib.")

# def mad_lib():
#   noun:str = str(input("Ënter a noun: "))
#   adjective:str = str(input("Ënter an adjective: "))
#   verb:str = str(input("Ënter a verb: "))
#   print(f"Do you {verb} your {adjective} {noun}? That\'s hilarious!")

# if __name__ == "__main__":
#   mad_lib()
# or

SENTENCE_START : str = "Panaversity is fun. I learned to program and used Python to make my "

def main():
    adjective: str = input("Enter an adjective and press enter: ")
    noun: str = input("Enter a noun and press enter: ")
    verb: str = input("Enter a verb and press enter: ")

    # print(f"{SENTENCE_START} {adjective} {noun} {verb}.")

    print(SENTENCE_START + adjective + " " + noun + " " + verb + ".")

if __name__ == "__main__":
    main()
# Out:
# 07_tiny_mad_lib.
# Enter an adjective and press enter: h
# Enter a noun and press enter: w
# Enter a verb and press enter: v
# Panaversity is fun. I learned to program and used Python to make my h w v.
