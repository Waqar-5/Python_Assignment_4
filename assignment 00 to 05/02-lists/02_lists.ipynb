# %%
print("01_add_many_number")

def add_number(numbers)->int:
  num:int = 0
  for i in numbers:
    num += i
  return num

def main():
  numbers:list[int] = [1, 2, 3, 4, 5]
  sum = add_number(numbers)
  print(sum)

if __name__ == "__main__":
  main()
# Out:
# 01_add_many_number
# 15

# %%
print("02_double_list")

def main():
  numbers:list[int] = [1, 2, 3, 4, 5]
  for i in range(len(numbers)):
    index = numbers[i]
    numbers[i] = index * 2
  print(numbers)

if __name__ == "__main__":
  main()
# Out:
# 02_double_lis
# [2, 4, 6, 8, 10]

# %%
print("04_flowing_with_data_structures.")

def add_three_copies(lst, data):
  for i in range(3):
    lst.append(data)

def main():
  message = input("Enter a message to copy: ")
  lst = []
  print("Before list: ", lst)
  add_three_copies(lst, message)
  print("After lst: ", lst)

if __name__ == "__main__":
  main()
# Out:
# 04_flowing_with_data_structures.
# Enter a message to copy: hello paksitan
# Before list:  []
# After lst:  ['hello paksitan', 'hello paksitan', 'hello paksitan']

# %%
print("05_get_first_element.")

def get_first_element(lst):
  print(lst[0])

def get_lst():
  lst = []
  element:str = input("Enter an element to add to the list: ")
  while element != "":
    lst.append(element)
    element = input("Enter an element to add to the list: ")
  return lst

def main():
  lst = get_lst()
  get_first_element(lst)

if __name__ == "__main__":
  main()
# Out:
# 05_get_first_element.
# Enter an element to add to the list: a
# Enter an element to add to the list: s
# Enter an element to add to the list: d
# Enter an element to add to the list: r
# Enter an element to add to the list: y
# Enter an element to add to the list: i
# Enter an element to add to the list: r
# Enter an element to add to the list:
# a

# %%
print("06_get_last_element.")

def get_last_element(lst):
  print(lst[-1])

def get_lst():
  lst = []
  element:str = input("Enter an element to add to the list: ")
  while element != "":
    lst.append(element)
    element = input("Enter an element to add to the list: ")
  return lst


def main():
  lst = get_lst()
  get_last_element(lst)



if __name__ == "__main__":
  main()
# Out:
# 06_get_last_element.
# Enter an element to add to the list: 2
# Enter an element to add to the list: 2
# Enter an element to add to the list: 3
# Enter an element to add to the list: 4
# Enter an element to add to the list: 6
# Enter an element to add to the list:
# 6

# %%
print("07_get_list.")

def main():
  lst = []
  val = input("Enter a value to add to the list: ")
  while val:
    lst.append(val)
    val = input("Enter a value to add to the list: ")
  print("Here's the list: ", lst)

if __name__ == "__main__":
  main()
# Out:
# 07_get_list.
# Enter a value to add to the list: ali
# Enter a value to add to the list: amna
# Enter a value to add to the list: yusra
# Enter a value to add to the list: yashal
# Enter a value to add to the list: kiswa
# Enter a value to add to the list: sohail
# Enter a value to add to the list:
# Here's the list:  ['ali', 'amna', 'yusra', 'yashal', 'kiswa', 'sohail']

# %%
print("08_shorten.")

MAX_LENGTH:int = 3

def shorten(lst):
  while len(lst) > MAX_LENGTH:
    last_element = lst.pop()
    print(last_element)

def get_lst():
    lst = []
    element = input("Enter an element to add the list: ")
    while element != "":
      lst.append(element)
      element = input("Enter an element to add the list: ")
    return lst

def main():
    lst = get_lst()
    shorten(lst)

if __name__ == "__main__":
    main()
# Out:
# 08_shorten.
# Enter an element to add the list: fgh
# Enter an element to add the list: uio
# Enter an element to add the list: vgy
# Enter an element to add the list: ert
# Enter an element to add the list: bhi
# Enter an element to add the list: uio
# Enter an element to add the list:
# uio
# bhi
# ert
