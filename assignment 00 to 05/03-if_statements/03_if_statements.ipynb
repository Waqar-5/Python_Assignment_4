# %%
print("01_print_events.")

def main():
  for i in range(40):
    even = i * 2
    print(even)
    # print("Here is 20 even numbers are: ", i * 2)

if __name__ == "__main__":
  main()
# Out:
# 01_print_events.
# Here is 20 even numbers are:  0
# Here is 20 even numbers are:  2
# Here is 20 even numbers are:  4
# Here is 20 even numbers are:  6
# Here is 20 even numbers are:  8
# Here is 20 even numbers are:  10
# Here is 20 even numbers are:  12
# Here is 20 even numbers are:  14
# Here is 20 even numbers are:  16
# Here is 20 even numbers are:  18
# Here is 20 even numbers are:  20
# Here is 20 even numbers are:  22
# Here is 20 even numbers are:  24
# Here is 20 even numbers are:  26
# Here is 20 even numbers are:  28
# Here is 20 even numbers are:  30
# Here is 20 even numbers are:  32
# Here is 20 even numbers are:  34
# Here is 20 even numbers are:  36
# Here is 20 even numbers are:  38
# Here is 20 even numbers are:  40
# Here is 20 even numbers are:  42
# Here is 20 even numbers are:  44
# Here is 20 even numbers are:  46
# Here is 20 even numbers are:  48
# Here is 20 even numbers are:  50
# Here is 20 even numbers are:  52
# Here is 20 even numbers are:  54
# ...

# %%
print("02_international_voting_age.")

Peturksbouipo:int = 16
Stanlau:int = 25
Mayengua:int = 48

age:int = int(input("How old are you? "))

def main():
  if age >= Peturksbouipo:
    print(f"Your age {age}. You are eligible to vote in Peturksbouipo!")
  else:
    print(f"Your age {age}. You are not eligible to vote in Peturksbouipo!")
if age >= Stanlau:
  print(f"Your age {age}. You are eligible to vote in Stanlau!")
else:
  print(f"Your age {age}. You are not eligible to vote in Stanlau!")
if age >= Mayengua:
  print(f"Your age {age}. You are eligible to vote in Mayengua!")
else:
  print(f"Your age {age}. You are not eligible to vote in Mayengua!")

if __name__ == "__main__":
  main()
# Out:
# 02_international_voting_age.
# How old are you? 45
# Your age 45. You are eligible to vote in Stanlau!
# Your age 45. You are not eligible to vote in Mayengua!
# Your age 45. You are eligible to vote in Peturksbouipo!

# %%
print("03_leap_year.")

def leap_year():
  year:int = int(input("Enter as year: "))

  if year % 4 == 0:
    if year % 100 == 0:
      if year % 400 == 0:
        print(f"{year} is a leap year.")
      else:
        print(f"{year} is not a leap year.")
    else:
        print(f"{year} is not a leap year.")
  else:
        print(f"{year} is not a leap year.")

if __name__ == "__main__":
  leap_year()
# Out:
# 03_leap_year.
# Enter as year: 2018
# 2018 is not a leap year.

# %%
print("04_tall_enough_to_ride.")

min_height:int = 50

def main():
  user:int = int(input("How tall are you? "))
  if user >= min_height:
    print("you are tall enough to ride.")
  else:
    print("You are not tall enough to ride. May be next year.")

if __name__ == "__main__":
  main()
# Out:
# 04_tall_enough_to_ride.
# How tall are you? 55
# you are tall enough to ride.

# %%
import random
print("05_random_numbers.")

def main():
  for i in range(10):
    num:list[int] = random.randint(1, 100)
    print(num)

if __name__ =="__main__":
  main()
# Out:
# 05_random_numbers
# 24
# 66
# 8
# 59
# 55
# 43
# 10
# 30
# 85
# 86
