# %%
print("00_choosing_returns.")

def choose_return(option):
  if option == "A":
    return "You chose option A"
  elif option == "B":
    return "You chose option B"
  elif option == "C":
    return "You chose option C"
  else:
    return "Invalid option. Please choose A, B, or C."

def main():
  print("Choose one of the following options: A, B, C.")
  option = input("Enter your choice: -> ")

  result = choose_return(option)
  print(result)

if __name__ == "__main__":
  main()
# Out:
# 00_choosing_returns.
# Choose one of the following options: A, B, C.
# Enter your choice: -> b
# Invalid option. Please choose A, B, or C.

# %%
print("01_greetings")

def greet(name):
  return f"Hello, {name}! Welcome to the program."

def main():
  name = input("Please enter your name: -> ")
  greeting_message = greet(name)
  print(greeting_message)

if __name__ == "__main__":
  main()
# Out:
# 01_greetings
# Please enter your name: -> Waqar
# Hello, Waqar! Welcome to the program.

# %%
from ctypes import string_at
print("02_in_range")

def in_range(number, start, end):
  if start <= number <= end:
    return True
  else:
    return False

def main():
  try:
    num = int(input("🔢 Enter a number: ->"))
    start = int(input("Enter the start of the range: ->"))
    end = int(input("Enter the end of the range: ->"))
  except ValueError:
    print(f"❌ Please enter valid integers.")
    return

  if in_range(num, start, end):
    print(f"✅ {num} is within the range of {start} and {end}")
  else:
    print(f"❌ {num} is not within the range of {start} and {end}")

if __name__ == "__main__":
  main()
# Out:
# 02_in_range
# 🔢 Enter a number: ->6
# Enter the start of the range: ->1
# Enter the end of the range: ->8
# ✅ 6 is within the range of 1 and 8

# %%
print("03_in_stock")


def in_stock(product, stock):
  if product in stock and stock[product] > 0:
    return True
  else:
    return False

def main():
  stock = {
       "apple": 10,
        "banana": 0,
        "orange": 5,
        "grapes": 2
  }

  product = input("Enter the product name to check its stock: -> ")

  if in_stock(product, stock):
    print(f"✅ {product.capitalize()} is in stock!")
  else:
    print(f"❌ {product.capitalize()} is not in stock!")

if __name__ == "__main__":
  main()
# Out:
# 03_in_stock
# Enter the product name to check its stock: -> orange
# ✅ Orange is in stock!

# %%
print("04_multiple_returns")

import math

def anaylze_number(number):
  square = number ** 2
  cube = number ** 3
  square_root = math.sqrt(number)

  return square, cube, square_root

def main():
  try:
    num = float(input("🔢 Enter a number"))
  except ValueError:
    print("❌ Please enter a valid number.")
    return

  square, cube, square_root = anaylze_number(num)

  print(f"✅ The square of {num} is: {square}")
  print(f"✅ The cube of {num} is: {cube}")
  print(f"✅ The square_root of {num} is: {square_root}")

if __name__ =="__main__":
  main()
# Out:
# 04_multiple_returns
# 🔢 Enter a number2
# ✅ The square of 2.0 is: 4.0
# ✅ The cube of 2.0 is: 8.0
# ✅ The square_root of 2.0 is: 1.4142135623730951

# %%
print("05_subtract_7")

def subtract_seven(number):
  return number - 7

def main():
  try:
    num = float(input("🔢 Enter a number: → "))
  except ValueError:
    print("❌ Please enter a valid number.")
    return

  result = subtract_seven(num)
  print(f"✅ After subtracting 7, the result is: {result}")

if __name__ == "__main__":
  main()
# Out:
# 05_subtract_7
# 🔢 Enter a number: → 55
# ✅ After subtracting 7, the result is: 48.0
